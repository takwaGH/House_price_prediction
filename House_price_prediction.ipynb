# %% [markdown]
# # Importing the dataset and the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures 
#from sklearn.metrics import mean_squared_error
#from scipy import stats

# %% [markdown]
# # Some informations about the dataset

# %%
data=pd.read_csv("C:\\Users\\Pc\\Desktop\\GoMyCode\\kc_house_data.csv", sep=",")
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# # Exploring some missing data

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# As we can see there is no missisng data in our dataset

# %% [markdown]
# # Let's explore the dataset by visualization

# %%
sns.displot(data['price'])

# %% [markdown]
# # Correlation between features

# %%
corr = data.corr()
corr
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %% [markdown]
# As we can see from the correlation matrix that the feature "sqft_living" has the most importatnt correlation coefficient with the "price".So we will

# %% [markdown]
# So it's clear that we will use **sqft_living** as independent variable to predict house price for the linear regression model and **sqft_living, grade, sqft_above, sqft_living15, bathrooms** for our Multiple linear regression.

# %% [markdown]
# 1. Linear Regression

# %% [markdown]
# **Splitting Training and Test Data**

# %%
X = data[["sqft_living"]]
y = data[["price"]]
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=40) 
#80% will be trained data and 20% will be testing data 
print(X.shape, x_train.shape, x_test.shape)
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (21613, 1) (17290, 1) (4323, 1)
# (21613, 1) (17290, 1) (4323, 1)

# %% [markdown]
# **Building our model**

# %%
#loading lineair regression model
lin_reg_model=LinearRegression()  

#fitting the training data
lin_reg_model.fit(x_train,y_train)  

#Prediction on Training data

predicted=lin_reg_model.predict(x_test)

# %% [markdown]
# **Plotting our model**

# %%
plt.scatter(X,y,color="r")
plt.title("Linear Regression")
plt.ylabel("sqft_living")
plt.xlabel("price")
plt.plot(X,lin_reg_model.predict(X),color="k")
plt.show()

# %%
#testing our model
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62451720102.954
# R squared 0.5035535751151091

# %% [markdown]
# 2. Multiple regression model

# %% [markdown]
# **Splitting Training and Test Data**

# %%
features = ["sqft_living","grade","sqft_above","sqft_living15","bathrooms"]
X = data[features]
y = data[["price"]]
# Split the data into training data and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8)

# %% [markdown]
# **Building our model**

# %%
# Build Multiple regression model
multiple_regression_model = linear_model.LinearRegression()
# Fit data into the model
multiple_regression_model.fit(X_train, y_train)
# Using the fitted model to predict target value for our test set
pred = multiple_regression_model.predict(X_test)

# %% [markdown]
# **Testing our model**

# %%
#Testing our model 
print("MSE", mean_squared_error(y_test,pred))
print("R squared", metrics.r2_score(y_test,pred))
# Out:
# MSE 65841019735.17254
# R squared 0.5426386789029115

# %% [markdown]
# **Linear regression VS Multiple linear regression**

# %% [markdown]
# According to our evaluation, Multiple Regression Model has lower MSE than Linear Regression Model;
# Besides, the R squared for training data and test data of Multiple Regression Model
# are both higher than Linear Regression Model.
# So we conclude that multiple regression model are better than linear regression model for predicting the house price.

# %% [markdown]
# 3. Polynomial model

# %% [markdown]
# **Building our model**

# %%
X = data[["sqft_living"]]
y = data[["price"]]
lg = LinearRegression() 
poly = PolynomialFeatures(degree = 2)
#fitting our model
x_poly=poly.fit_transform(X)
print("x before transformation: ", X)
print("x after transformation: ", x_poly)
lg.fit(x_poly, y)
# Out:
# x before transformation:         sqft_living
# 0             1180
# 1             2570
# 2              770
# 3             1960
# 4             1680
# ...            ...
# 21608         1530
# 21609         2310
# 21610         1020
# 21611         1600
# 21612         1020
#
# [21613 rows x 1 columns]
# x after transformation:  [[1.0000e+00 1.1800e+03 1.3924e+06]
#  [1.0000e+00 2.5700e+03 6.6049e+06]
#  [1.0000e+00 7.7000e+02 5.9290e+05]
#  ...
#  [1.0000e+00 1.0200e+03 1.0404e+06]
#  [1.0000e+00 1.6000e+03 2.5600e+06]
#  [1.0000e+00 1.0200e+03 1.0404e+06]]
# LinearRegression()

# %%
x_test_=poly.fit_transform(x_test)
y_pred=lg.predict(x_test_)

# %%
plt.scatter(X, y, color="r")
plt.title("Linear regression")
plt.ylabel("sqft_living")
plt.xlabel("price")
plt.plot(X, lg.predict(poly.fit_transform(X)), color="k")

# %%
print("MSE", mean_squared_error(y_test,y_pred))
print("R squared", metrics.r2_score(y_test, y_pred))
# Out:
# MSE 214709341308.10822
# R squared -0.49146760465654427

# %% [markdown]
# at the end we conclude that the R squared for training data and test data of Multiple Regression Model are both higher than Linear Regression Model and polynomial regression.
#  So multiple regression model is the best model for predicting the house price .
